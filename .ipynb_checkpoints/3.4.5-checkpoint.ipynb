# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1*42/5, 2*42/5, 3*42/5, 4*42/5, 5.5*42/5, 8.5*42/5, 11.5*42/5, 14.5*42/5])
y = np.array([0, 1*0.067/5, 2.5*0.067/5, 4.5*0.067/5, 6*0.067/5, 7.5*0.067/5, 10.5*0.067/5, 12*0.067/5, 13*0.067/5])

x = np.array([0, 1*42/5, 2*42/5])
y1 = np.array([0, 1*0.067/5, 2.5*0.067/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ нач", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid()

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Феррит")
plt.ylim(-0.02, 0.2)
plt.legend()
plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Феррит.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1*42/5, 2*42/5, 3*42/5, 4*42/5, 5.5*42/5, 8.5*42/5, 11.5*42/5, 14.5*42/5])
y = np.array([0, 1*0.067/5, 2.5*0.067/5, 4.5*0.067/5, 6*0.067/5, 7.5*0.067/5, 10.5*0.067/5, 12*0.067/5, 13*0.067/5])

x = np.array([0, 4*42/5])
y1 = np.array([0, 6*0.067/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)
x_line1 = np.linspace(min(x1), x1[5], 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ max", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid()

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Феррит")
plt.ylim(-0.02, 0.2)
plt.legend()
plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Феррит, μ max.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 0.5*37.6/5, 1*37.6/5, 1.75*37.6/5, 2.25*37.6/5, 2.5*37.6/5, 2.75*37.6/5, 3.75*37.6/5, 4.25*37.6/5])
y = np.array([0, 0.5*0.88/5, 1*0.88/5, 2.5*0.88/5, 4*0.88/5, 5.5*0.88/5, 6.25*0.88/5, 8*0.88/5, 8.5*0.88/5])

x = np.array([0, 0.5*37.6/5, 1*37.6/5])
y1 = np.array([0, 0.5*0.88/5, 1*0.88/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ нач", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid()

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Fe-Ni")
#plt.ylim(-0.1, 1)
plt.legend()
#plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Fe-Ni.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 0.5*37.6/5, 1*37.6/5, 1.75*37.6/5, 2.25*37.6/5, 2.5*37.6/5, 2.75*37.6/5, 3.75*37.6/5, 4.25*37.6/5])
y = np.array([0, 0.5*0.88/5, 1*0.88/5, 2.5*0.88/5, 4*0.88/5, 5.5*0.88/5, 6.25*0.88/5, 8*0.88/5, 8.5*0.88/5])

x = np.array([0, 2.75*37.6/5])
y1 = np.array([0, 6.25*0.88/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ max", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid()

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Fe-Ni")
#plt.ylim(-0.1, 1)
plt.legend()
plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Fe-Ni, μ max.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1*227/5, 1.75*227/5, 2.25*227/5, 3*227/5, 4*227/5, 5*227/5, 6.25*227/5, 7.5*227/5])
y = np.array([0, 1*0.4/5, 3*0.4/5, 4.25*0.4/5, 6*0.4/5, 7*0.4/5, 8*0.4/5, 9*0.4/5, 10*0.4/5])

x = np.array([0, 1*227/5])
y1 = np.array([0, 1*0.4/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ нач", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid()

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Fe-Si")
#plt.ylim(-0.1, 1)
plt.legend()
plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Fe-Si.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1*227/5, 1.75*227/5, 2.25*227/5, 3*227/5, 4*227/5, 5*227/5, 6.25*227/5, 7.5*227/5])
y = np.array([0, 1*0.4/5, 3*0.4/5, 4.25*0.4/5, 6*0.4/5, 7*0.4/5, 8*0.4/5, 9*0.4/5, 10*0.4/5])

x = np.array([0, 3*227/5])
y1 = np.array([0, 6*0.4/5])

t = 0.005  # Погрешности
z = 0.002
x_line = np.linspace(min(x1), max(x1), 1000)

# Интерполяция значений y
#y_interp = np.interp(x_line, x1, y)

# Интерполяция погрешностей
#t_interp = np.interp(x_line, x1, t)

# Закрашивание области погрешностей относительно точек
#lt.fill_between(x_line, y_interp - t_interp, y_interp + t_interp, alpha=0.3, color='green', label='Погрешность')

# Построение точек
plt.scatter(x1, y, color='red', s = 2, zorder=3)

#Построение апроксимации
a3, b = np.polyfit(x, y1, 1)
y_line = a3*x_line + b
plt.plot(x_line, y_line, label=f"y = {a3:.5f}x + {b:.3f}, μ max", color='blue')

# Добавление погрешностей
plt.errorbar(x1, y, xerr=t, yerr=z, linestyle='', color='black', capsize=2.5)

# Включение сетки
plt.grid(True)

plt.yticks(np.arange(-1, 1.1, 0.1))  # Шаг по Y = 0.2

plt.xlabel("H, A/м")
plt.ylabel("B, Тл")
plt.title("Зависимость В от Н, Fe-Si")
plt.ylim(-0.05, 0.85)
plt.legend()
plt.savefig('C:\\prog\\labs\\3.4.5\\Зависимость В от Н, Fe-Si, μ max.pdf')
plt.show()
